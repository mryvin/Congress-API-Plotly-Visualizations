# %%
def get_state_name(state_code):
    us_state_abbrev = {
        'AL': 'Alabama',
        'AK': 'Alaska',
        'AZ': 'Arizona',
        'AR': 'Arkansas',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'HI': 'Hawaii',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'IA': 'Iowa',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'ME': 'Maine',
        'MD': 'Maryland',
        'MA': 'Massachusetts',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MS': 'Mississippi',
        'MO': 'Missouri',
        'MT': 'Montana',
        'NE': 'Nebraska',
        'NV': 'Nevada',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NY': 'New York',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VT': 'Vermont',
        'VA': 'Virginia',
        'WA': 'Washington',
        'WV': 'West Virginia',
        'WI': 'Wisconsin',
        'WY': 'Wyoming',
        'AS': 'American Samoa',
        'DC': 'D.C.',
        'PR': 'Puerto Rico',
        'VI': 'U.S. Virgin Islands',
        'GU': 'Guam',
        'TT': 'Trust Territories'
    }
    state_name = us_state_abbrev.get(state_code.upper())
    return state_name

# %%
import json
new_data = [

]

with open('members_with_details_all_updated.json', 'w') as f:
    json.dump(new_data, f)

# %%
import json
import requests
import plotly.graph_objects as go
from bs4 import BeautifulSoup
from PIL import Image
from io import BytesIO
import math

# Load the JSON file
with open('members_with_details_all.json', 'r') as f:
    data = json.load(f)  

success = 0
failure = 0
count = 0

for i in range(math.ceil(len(data)/100)):
    i = i+9
    min = i * 100
    print(min)
    if i < 25:
        max = min + 100
    else:
        max = 2515

    with open('members_with_details_all_updated.json', 'r') as f:
        new_data = json.load(f)  
        
    # Loop through each object in the JSON
    for obj in data[min:max]:

        # Extract the full name
        full_name = obj['first_name'] + " " + obj['last_name']

        state = get_state_name(obj['state'])


        # Search for the Wikipedia page
        url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extract the URL of the main image
        infobox = soup.find('table', class_='infobox')
        if infobox:
            
            image_element = infobox.find('img')
            if image_element:
                main_image_url = image_element['src']

                main_image_url = "http:" + main_image_url

                if main_image_url.endswith("JPG"):
                    main_image_url = main_image_url[:-3] + "jpg"

                if main_image_url.endswith("jpeg"):
                    main_image_url = main_image_url[:-4] + "jpg"

                if main_image_url.endswith("png"):
                    main_image_url = main_image_url[:-3] + "jpg"

                # Add the photo attribute to the JSON object
                obj['photo'] = main_image_url
                success += 1

            else:
                print(f"No main image found in the infobox for {full_name}.")
                obj['photo'] = ""
                failure += 1
        else:
            
            url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}_(politician)'
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract the URL of the main image
            infobox = soup.find('table', class_='infobox')
            if infobox:
                
                image_element = infobox.find('img')
                if image_element:
                    main_image_url = image_element['src']

                    main_image_url = "http:" + main_image_url

                    if main_image_url.endswith("JPG"):
                        main_image_url = main_image_url[:-3] + "jpg"

                    if main_image_url.endswith("jpeg"):
                        main_image_url = main_image_url[:-4] + "jpg"

                    if main_image_url.endswith("png"):
                        main_image_url = main_image_url[:-3] + "jpg"

                    # Add the photo attribute to the JSON object
                    obj['photo'] = main_image_url
                    success += 1

                else:
                    print(f"No main image found in the infobox for {full_name}.")
                    obj['photo'] = ""
                    failure += 1
            else:
                url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}_({state.replace(" ", "_")}_politician)'
                response = requests.get(url)
                soup = BeautifulSoup(response.text, 'html.parser')

                # Extract the URL of the main image
                infobox = soup.find('table', class_='infobox')
                if infobox:
                    image_element = infobox.find('img')
                    if image_element:
                        main_image_url = image_element['src']

                        main_image_url = "http:" + main_image_url

                        if main_image_url.endswith("JPG"):
                            main_image_url = main_image_url[:-3] + "jpg"

                        if main_image_url.endswith("jpeg"):
                            main_image_url = main_image_url[:-4] + "jpg"

                        if main_image_url.endswith("png"):
                            main_image_url = main_image_url[:-3] + "jpg"

                        # Add the photo attribute to the JSON object
                        obj['photo'] = main_image_url
                        success += 1

                    else:
                        print(f"No main image found in the infobox for {full_name}.")
                        obj['photo'] = ""
                        failure += 1
                else:
                    url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}_(U.S._Senator)'
                    response = requests.get(url)
                    soup = BeautifulSoup(response.text, 'html.parser')
                    
                    # Extract the URL of the main image
                    infobox = soup.find('table', class_='infobox')
                    if infobox:
                        
                        image_element = infobox.find('img')
                        if image_element:
                            main_image_url = image_element['src']

                            main_image_url = "http:" + main_image_url

                            if main_image_url.endswith("JPG"):
                                main_image_url = main_image_url[:-3] + "jpg"

                            if main_image_url.endswith("jpeg"):
                                main_image_url = main_image_url[:-4] + "jpg"

                            if main_image_url.endswith("png"):
                                main_image_url = main_image_url[:-3] + "jpg"

                            # Add the photo attribute to the JSON object
                            obj['photo'] = main_image_url
                            success += 1
                        
                        else:
                            print(f"No main image found in the infobox for {full_name}.")
                            obj['photo'] = ""
                            failure += 1

                    else:
                        # Extract the full name
                        full_name = obj['full_name']

                        # Search for the Wikipedia page
                        url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}'
                        response = requests.get(url)
                        soup = BeautifulSoup(response.text, 'html.parser')

                        # Extract the URL of the main image
                        infobox = soup.find('table', class_='infobox')
                        if infobox:
                            image_element = infobox.find('img')
                            if image_element:
                                main_image_url = image_element['src']

                                main_image_url = "http:" + main_image_url

                                if main_image_url.endswith("JPG"):
                                    main_image_url = main_image_url[:-3] + "jpg"

                                if main_image_url.endswith("jpeg"):
                                    main_image_url = main_image_url[:-4] + "jpg"

                                if main_image_url.endswith("png"):
                                    main_image_url = main_image_url[:-3] + "jpg"

                                # Add the photo attribute to the JSON object
                                obj['photo'] = main_image_url
                                success += 1

                            else:
                                print(f"No main image found in the infobox for {full_name}.")
                                obj['photo'] = ""
                                failure += 1
                        else:
                            url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}_(politician)'
                            response = requests.get(url)
                            soup = BeautifulSoup(response.text, 'html.parser')

                            # Extract the URL of the main image
                            infobox = soup.find('table', class_='infobox')
                            if infobox:
                                image_element = infobox.find('img')
                                if image_element:
                                    main_image_url = image_element['src']

                                    main_image_url = "http:" + main_image_url

                                    if main_image_url.endswith("JPG"):
                                        main_image_url = main_image_url[:-3] + "jpg"

                                    if main_image_url.endswith("jpeg"):
                                        main_image_url = main_image_url[:-4] + "jpg"

                                    if main_image_url.endswith("png"):
                                        main_image_url = main_image_url[:-3] + "jpg"

                                    # Add the photo attribute to the JSON object
                                    obj['photo'] = main_image_url
                                    success += 1

                                else:
                                    print(f"No main image found in the infobox for {full_name}.")
                                    obj['photo'] = ""
                                    failure += 1
                            else:
                                url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}_({state.replace(" ", "_")}_politician)'
                                response = requests.get(url)
                                soup = BeautifulSoup(response.text, 'html.parser')

                                # Extract the URL of the main image
                                infobox = soup.find('table', class_='infobox')
                                if infobox:
                                    image_element = infobox.find('img')
                                    if image_element:
                                        main_image_url = image_element['src']

                                        main_image_url = "http:" + main_image_url

                                        if main_image_url.endswith("JPG"):
                                            main_image_url = main_image_url[:-3] + "jpg"

                                        if main_image_url.endswith("jpeg"):
                                            main_image_url = main_image_url[:-4] + "jpg"

                                        if main_image_url.endswith("png"):
                                            main_image_url = main_image_url[:-3] + "jpg"

                                        # Add the photo attribute to the JSON object
                                        obj['photo'] = main_image_url
                                        success += 1

                                    else:
                                        print(f"No main image found in the infobox for {full_name}.")
                                        obj['photo'] = ""
                                        failure += 1
                                else:
                                    url = f'https://en.wikipedia.org/wiki/{full_name.replace(" ", "_")}_(U.S._Senator)'
                                    response = requests.get(url)
                                    soup = BeautifulSoup(response.text, 'html.parser')

                                    # Extract the URL of the main image
                                    infobox = soup.find('table', class_='infobox')
                                    if infobox:
                                        image_element = infobox.find('img')
                                        if image_element:
                                            main_image_url = image_element['src']

                                            main_image_url = "http:" + main_image_url

                                            if main_image_url.endswith("JPG"):
                                                main_image_url = main_image_url[:-3] + "jpg"

                                            if main_image_url.endswith("jpeg"):
                                                main_image_url = main_image_url[:-4] + "jpg"

                                            if main_image_url.endswith("png"):
                                                main_image_url = main_image_url[:-3] + "jpg"

                                            # Add the photo attribute to the JSON object
                                            obj['photo'] = main_image_url
                                            success += 1

                                        else:
                                            print(f"No main image found in the infobox for {full_name}.")
                                            obj['photo'] = ""
                                            failure += 1
                                    
                                    else:
                                        print(f"No article found for {full_name}.")
                                        obj['photo'] = ""
                                        failure += 1
    
    
    new_data = new_data + data[min:max]

    # Save the updated JSON file
    with open('members_with_details_all_updated.json', 'w') as f:
        json.dump(new_data, f)
# Out:
# 900
# No article found for Charles W. "Chip" Pickering.
# No article found for William L. Jenkins.
# No article found for Jim Gibbons.
# No main image found in the infobox for Robert A. Brady.
# No article found for James B. Allen.
# No article found for Edwin V. W. Zschau.
# No article found for John Young.
# No article found for Edward Young.
# 1000
# No article found for Larry Winn Jr..
# No article found for Robert C. Wilson.
# No article found for Charles O. Whitley Sr..
# No article found for James H. Weaver.
# No article found for J. C. Watts Jr..
# No article found for Mike Ward.
# No article found for Joe D. Waggonner Jr..
# No article found for James G. Tucker Jr. (Jim Guy).
# No article found for Estaban Edward Torres.
# 1100
# No main image found in the infobox for William M. Thomas.
# No article found for G. Taylor.
# No article found for Charles H. Taylor.
# No article found for W. J. (Billy) Tauzin.
# No article found for Robert M. (Robin) Tallon.
# ...

# %%
import json

with open('members_with_details_all_updated.json') as f:
    data = json.load(f)

for item in data:
    if 'photo' not in item:
        item['photo'] = ""

# write the updated data back to the file
with open('members_with_details_all_updated.json', 'w') as f:
    json.dump(data, f)

# %%
import json

with open('members_with_details_all_updated.json') as f:
    data = json.load(f)

count = 0
total = 0
for item in data:
    total += 1
    if item['photo'] == "":
        count += 1

print(count)
print(total)
# Out:
# 235
# 2515

# %%
import json

with open('members_with_details_all_updated.json', 'r') as f:
    data = json.load(f)

for item in data:
    if item.get('current_member') == True:
        if item.get('bioguide_id') == 'V000137':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/8/83/Senator_Vance_official_portrait._118th_Congress.jpg'
        if item.get('bioguide_id') == 'R000122':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/d8/Jack_Reed_official_photo_%28cropped%29.jpg'
        if item.get('bioguide_id') == 'M001169':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/4/47/Chris_Murphy%2C_official_portrait%2C_113th_Congress_%28cropped%29.jpg'
        if item.get('bioguide_id') == 'L000570':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/b/b5/Ben_Ray_Lujan%2C_117th_Congress_portrait_2.jpg'
        if item.get('bioguide_id') == 'D000563':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/4/49/Dick_Durbin_117th_Congress_portrait_%281%29_%28cropped%29.jpeg'
        if item.get('bioguide_id') == 'C001070':
            item['photo'] = 'https://commons.wikimedia.org/wiki/File:Bob_Casey_Jr._official_photo.jpg'
        if item.get('bioguide_id') == 'O000175':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/3b/Congressman_Andy_Ogles_2022.jpg'
        if item.get('bioguide_id') == 'N000193':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/0/05/Rep._Zach_Nunn_official_photo%2C_118th_Congress.jpg'
        if item.get('bioguide_id') == 'M001218':
            item['photo'] = 'https://commons.wikimedia.org/wiki/File:Rep._Rich_McCormick_official_photo,_118th_Congress_(1).jpg'
        if item.get('bioguide_id') == 'L000600':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/cb/Nick_langworthy_portrait.jpg'
        if item.get('bioguide_id') == 'G000599':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/db/Daniel_Goldman_Portrait.jpg'
        if item.get('bioguide_id') == 'D000530':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/1b/Rep._Chris_Deluzio_-_118th_Congress.jpg'
        if item.get('bioguide_id') == 'C001132':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2a/Rep._Eli_Crane_official_photo%2C_118th_Congress.jpg'
        if item.get('bioguide_id') == 'M000687':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/b/ba/Kweisi_Mfume%2C_official_portrait%2C_116th_Congress.jpg'
        if item.get('bioguide_id') == 'R000579':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/a/a8/Pat_Ryan_117th_Congress_portrait.jpeg'
        if item.get('bioguide_id') == 'S000168':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/e0/REP.MES_Headshot_%28cropped_2%29.jpg'
        if item.get('bioguide_id') == 'M001214':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/6/6a/Frank_Mrvan_117th_U.S_Congress.jpg'
        if item.get('bioguide_id') == 'G000593':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/ee/Rep._Carlos_Gimenez_official_photo%2C_117th_Congress.jpg'
        if item.get('bioguide_id') == 'F000472':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/6/64/Scott_Franklin%2C_117th_Congress_portrait.jpg'
        if item.get('bioguide_id') == 'T000165':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/d6/Tom_Tiffany.jpg'
        if item.get('bioguide_id') == 'M001210':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/f/fe/Rep._Greg_Murphy_116th_Congress_Portrait.jpg'
        if item.get('bioguide_id') == 'G000586':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/17/Chuy_Garcia_official_portrait.jpg'
        if item.get('bioguide_id') == 'S001214':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/57/Greg_Steube_117th_Congress.jpeg'
        if item.get('bioguide_id') == 'S001205':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/75/Mary_Gay_Scanlon%2C_official_portrait%2C_2018.jpg'
        if item.get('bioguide_id') == 'G000582':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Official_portrait_of_Resident_Commissioner_Jenniffer_Gonzalez.jpg'
        if item.get('bioguide_id') == 'F000466':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/3a/Brian_Fitzpatrick_official_congressional_photo.jpg'
        if item.get('bioguide_id') == 'F000465':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/e3/Drew_Ferguson_115th_Congress_2.jpeg'
        if item.get('bioguide_id') == 'C001110':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/30/J._Luis_Correa.jpg'
        if item.get('bioguide_id') == 'C001103':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/7b/Buddy_Carter%2C_Official_Portrait%2C_114th_Congress.jpg'
        if item.get('bioguide_id') == 'H001072':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/3d/French_Hill_official_photo.jpg'
        if item.get('bioguide_id') == 'S001195':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2e/Congressman_Jason_T._Smith.jpg'
        if item.get('bioguide_id') == 'B001282':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/94/Andy_Barr_official_congressional_photo.jpg'
        if item.get('bioguide_id') == 'P000604':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/21/Donald_Payne_Jr_Official_Portrait_113rd_Congress.jpg'
        if item.get('bioguide_id') == 'W000804':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/5b/Rob_Wittman_117th_Congress.jpeg'
        if item.get('bioguide_id') == 'G000568':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/ec/Morgan_Griffith%2C_Official_Portrait%2C_112th_Congress_B.jpg'
        if item.get('bioguide_id') == 'K000375':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/22/Bill_Keating_clerk_photo.jpg'
        if item.get('bioguide_id') == 'C001087':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/12/Rick_Crawford_117th_Congress_portrait.jpeg'
        if item.get('bioguide_id') == 'J000288':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/9e/Hank_Johnson_official_photo_2.jpg'
        if item.get('bioguide_id') == 'S000185':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/b/b5/BobbyScott.jpg'
        if item.get('bioguide_id') == 'R000395':
            item['photo'] = 'https://commons.wikimedia.org/wiki/File:Hal_Rogers_Official_Photo_2010.JPG'
        if item.get('bioguide_id') == 'W000795':
            item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/59/Joe_Wilson_official_congressional_photo.jpg'
        
    if item.get('bioguide_id') == 'Y000033':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/0/0a/Don_Young%2C_official_portrait%2C_116th_Congress.jpg'
    if item.get('bioguide_id') == 'T000254':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/da/Strom_Thurmond%2C_c_1961_%28cropped%29.jpg'
    if item.get('bioguide_id') == 'P000398':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/b/b0/William_R._Poage_1977_congressional_photo.jpg'
    if item.get('bioguide_id') == 'U000031':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/e9/FredUptonofficial_%28cropped3%29.jpg'
    if item.get('bioguide_id') == 'D000191':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/e1/Peter_DeFazio_official_photo.jpg'
    if item.get('bioguide_id') == 'M001120':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/31/John_Murtha_portrait_2008.jpg'
    if item.get('bioguide_id') == 'P000523':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2f/David_Price%2C_115th_Congress_official_photo.jpg'
    if item.get('bioguide_id') == 'C000754':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/39/Jim_Cooper%2C_Official_Portrait%2C_ca2013.jpg'
    if item.get('bioguide_id') == 'Q000013':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/96/JimmyQuillen.jpg'
    if item.get('bioguide_id') == 'C000488':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/a/a6/BillClaySr.jpg'
    if item.get('bioguide_id') == 'D000203':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/8/83/Kika_de_la_Garza_-_Flickr_-_USDAgov.jpg'
    if item.get('bioguide_id') == 'C001041':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/ec/Hillary_Clinton_by_Gage_Skidmore_4_%28cropped%29.jpg'
    if item.get('bioguide_id') == 'M000087':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/32/Carolyn_Maloney%2C_official_portrait%2C_116th_congress.jpg'
    if item.get('bioguide_id') == 'E000084':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/en/3/30/Jack_Edwards_%28Congressman%29.jpg'
    if item.get('bioguide_id') == 'S000142':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/18/Patschroeder.jpg'
    if item.get('bioguide_id') == 'H000324':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/6/6e/Alcee_Hastings_Official_portrait_108th_Congress.jpg'
    if item.get('bioguide_id') == 'L000265':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/a/a7/Elliott_Levitas-98th_Congress_%281973%29.jpeg'
    if item.get('bioguide_id') == 'O000166':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/c3/Butch_Otter_2017.jpg'
    if item.get('bioguide_id') == 'C000542':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/0/0d/Dan_Coats_official_DNI_portrait.jpg'
    if item.get('bioguide_id') == 'H000905':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/7e/WHuddleston.jpg'
    if item.get('bioguide_id') == 'R000395':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/4/4a/Hal_Rogers_Official_Photo_2010.JPG'
    if item.get('bioguide_id') == 'T000058':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2f/Billy_tauzin.jpg'
    if item.get('bioguide_id') == 'B000072':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/0/07/Richard_Baker%2C_109th_Congress_photo_portrait.jpg'
    if item.get('bioguide_id') == 'D000566':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/f/f6/DaveDurenberger.jpg'
    if item.get('bioguide_id') == 'M000865':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/ce/Sonnyvmontgomery.jpg'
    if item.get('bioguide_id') == 'R000571':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/a/af/Denny_Rehberg%2C_official_portrait%2C_111th_Congress.jpg'
    if item.get('bioguide_id') == 'S000622':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/38/Virginia_Smith.jpg'
    if item.get('bioguide_id') == 'W000227':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/8/86/1975_pg122_James_H._Weaver.jpg'
    if item.get('bioguide_id') == 'C001070':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/30/Bob_Casey_Jr._official_photo.jpg'
    if item.get('bioguide_id') == 'L000559':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/6/64/James_Langevin_official_portrait.jpg'
    if item.get('bioguide_id') == 'A000017':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Jim_Abourezk.jpg'
    if item.get('bioguide_id') == 'D000534':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/20/John_J._Duncan%2C_Sr.jpg'
    if item.get('bioguide_id') == 'G000072':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/8/8b/GarnNASA.jpg'
    if item.get('bioguide_id') == 'S000601':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/eb/Peter_Plympton_Smith.jpg'
    if item.get('bioguide_id') == 'M000933':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/9f/James_Moran_Official_Congressional_Portrait.jpg'
    if item.get('bioguide_id') == 'K000188':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/90/Ron_Kind%2C_Official_Portrait%2C_115th_Congress.jpg'
    if item.get('bioguide_id') == 'J000126':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/b/ba/Eddie_Bernice_Johnson_official_portrait_116th_Congress.jpg'
    if item.get('bioguide_id') == 'T000034':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/6/63/Congressman_Robin_Tallon.jpg'
    if item.get('bioguide_id') == 'R000072':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/59/Arthur_Ravenel_Jr.jpg'
    if item.get('bioguide_id') == 'D000482':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mike_Doyle%2C_official_portrait%2C_116th_Congress.jpg'
    if item.get('bioguide_id') == 'B001227':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/0/00/Bobbrady.jpeg'
    if item.get('bioguide_id') == 'W000793':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/4/4c/David_Wu_headshot_2006.jpg'
    if item.get('bioguide_id') == 'R000577':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/92/Tim_Ryan_portrait.jpg'
    if item.get('bioguide_id') == 'C000266':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/8/8e/SteveChabot.jpg'
    if item.get('bioguide_id') == 'H001032':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/c4/Rep_Holt_Official_Headshot.jpg'
    if item.get('bioguide_id') == 'P000323':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/9d/Chip_Pickering%2C_2016.jpg'
    if item.get('bioguide_id') == 'O000085':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/53/John_Olver%2C_Official_Portrait%2C_111th_Congress.jpg'
    if item.get('bioguide_id') == 'H000878':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/3e/Carroll_Hubbard_Jr.-102nd_Congress_%281991%29.jpeg'
    if item.get('bioguide_id') == 'W000636':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/3e/Larry_Winn.jpeg'
    if item.get('bioguide_id') == 'L000305':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/db/Lightfoot.jpg'
    if item.get('bioguide_id') == 'C000191':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/cb/Carson_julia.jpg'
    if item.get('bioguide_id') == 'R000515':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/1f/Bobby_Rush_official_portrait.jpg'
    if item.get('bioguide_id') == 'W000314':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/98/RobertWexlerPhoto.jpg'
    if item.get('bioguide_id') == 'S000586':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/4/4e/LJSmith.png'
    if item.get('bioguide_id') == 'K000306':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/de/Jim_Kolbe.png'
    if item.get('bioguide_id') == 'R000417':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/8/88/Carlos_Romero_Barcelo_%28cropped%29.png'
    if item.get('bioguide_id') == 'B000362':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/4/46/Jaime_Ben%C3%ADtez.jpg'
    if item.get('bioguide_id') == 'F000435':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/6/64/Fuster.jpg'
    if item.get('bioguide_id') == 'S001077':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/ec/Fof%C3%B3_Iosefa_Fiti_Sunia_99th_Congress_1985.jpg'
    if item.get('bioguide_id') == 'B000551':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/54/Ben_Blaz.jpg'
    if item.get('bioguide_id') == 'H000981':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/6/6a/DuncanHunter.jpg'
    if item.get('bioguide_id') == 'S000062':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/50/Ronald_Sarasin_%282%29.jpeg'
    if item.get('bioguide_id') == 'D000051':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2a/George_Darden_Headshot.jpg'
    if item.get('bioguide_id') == 'H000340':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/0/0d/Charles_Floyd_Hatcher.jpg'
    if item.get('bioguide_id') == 'K000360':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/a/a8/Senator_Mark_Kirk_official_portrait.jpg'
    if item.get('bioguide_id') == 'N000003':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/5b/David_Nagle-102nd_Congress_%281991%29.jpeg'
    if item.get('bioguide_id') == 'F000456':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/5b/John_Fleming_official_photo.jpg'
    if item.get('bioguide_id') == 'H000390':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/e5/JimmyHayes.jpg'
    if item.get('bioguide_id') == 'H000901':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/ef/Jerry_Huckaby_Scan_Doc0002.jpg'
    if item.get('bioguide_id') == 'B000592':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/13/Ambassador_Boggs.jpg'
    if item.get('bioguide_id') == 'D000131':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/7b/Robert_William_Davis.jpg'
    if item.get('bioguide_id') == 'C000261':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/e1/John_Cavanaugh_III-96th_Congress_%281979%29.jpeg'
    if item.get('bioguide_id') == 'G000152':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/c2/Jimgibbons.jpg'
    if item.get('bioguide_id') == 'F000141':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/32/Hamilton_Fish_IV.jpg'
    if item.get('bioguide_id') == 'M000472':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/0/02/Army_Secretary_John_McHugh.jpg'
    if item.get('bioguide_id') == 'B000817':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/5/54/WKBrewster.jpg'
    if item.get('bioguide_id') == 'W000210':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/e/e1/Watts.JPG'
    if item.get('bioguide_id') == 'S000607':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/31/Robert_Freeman_Smith.jpg'
    if item.get('bioguide_id') == 'P000112':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/3c/Lizzypatterson.jpg'
    if item.get('bioguide_id') == 'J000099':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/15/John_Jenrette.png'
    if item.get('bioguide_id') == 'H000719':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/b/b3/Kenneth_Lamar_Holland.jpg'
    if item.get('bioguide_id') == 'M000105':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/c2/Congressman_James_Mann.jpg'
    if item.get('bioguide_id') == 'R000308':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/f/f3/Clint_Roberts.png'
    if item.get('bioguide_id') == 'R000582':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/3/37/Phil_Roe_official_photo.jpg'
    if item.get('bioguide_id') == 'P000080':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/9/9e/Stanford_Parris.jpg'
    if item.get('bioguide_id') == 'C000293':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/en/e/e2/Rod_Chandler.jpg'
    if item.get('bioguide_id') == 'B000177':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/20/Thomas_M._Barrett%2C_U.S._Ambassador.jpg'
    if item.get('bioguide_id') == 'A000121':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/74/George_Allen_official_portrait.jpg'
    if item.get('bioguide_id') == 'F000151':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/1/1e/Joseph_L._Fisher.jpg'
    if item.get('bioguide_id') == 'B000966':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2d/Jim_Broyhill.jpg'
    if item.get('bioguide_id') == 'H000344':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/22/Paul_G._Hatfield.jpg'
    if item.get('bioguide_id') == 'S000597':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2b/Nick_Smith.jpg'
    if item.get('bioguide_id') == 'S000844':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/c/cf/Newton_Steers.jpg'
    if item.get('bioguide_id') == 'W000018':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/7/7b/Joe_d_waggonner_jr.jpg'
    if item.get('bioguide_id') == 'S000669':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/d5/Gene_Snyder.jpg'
    if item.get('bioguide_id') == 'B000567':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Micheal_Blouin.png'
    if item.get('bioguide_id') == 'H000624':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/2/2a/Elwood_Hillis_%281986%29.jpeg'
    if item.get('bioguide_id') == 'T000188':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/d/d1/Bill_Thomas%2C_official_photo_portrait_color.jpg'
    if item.get('bioguide_id') == 'A000127':
        item['photo'] = 'https://upload.wikimedia.org/wikipedia/commons/f/f8/James_Allen_%28D-AL%29.jpg'
    if item.get('bioguide_id') == '':
        item['photo'] = ''
    if item.get('bioguide_id') == '':
        item['photo'] = ''
    if item.get('bioguide_id') == '':
        item['photo'] = ''
    if item.get('bioguide_id') == '':
        item['photo'] = ''
    if item.get('bioguide_id') == '':
        item['photo'] = ''
        
# Save the updated JSON file
with open('members_with_details_all_updated2.json', 'w') as f:
    json.dump(data, f)

# %%
import json

with open('members_with_details_all_updated2.json') as f:
    data = json.load(f)

count = 0
for item in data:
    if item['photo'] == "":
        if item['state'] == "AL":
            print(item)
        count += 1

print(count)
# Out:
# {'bioguide_id': 'B001008', 'birth_year': '1928', 'sponsored_legislation_count': 38, 'cosponsored_legislation_count': 863, 'current_member': None, 'death_year': '2018', 'full_name': 'John Buchanan', 'honorific_name': None, 'first_name': 'JOHN', 'last_name': 'BUCHANAN', 'party': 'Republican', 'state': 'AL', 'years_served': 16, 'year_of_first_term': 1965, 'year_of_last_term': 1981, 'photo': ''}
# 100
